# %% [markdown]
# # Import Dependencies

# %%
import sys
sys.path.append(r'C:\Users\YH006_new\Desktop\Fingers-Gesture-Recognition')

import numpy as np
import torch
import Source.fgr.models as models
from Source.fgr.utils import train_test_split_by_gesture

from Source.fgr.pipelines import Data_Pipeline
from Source.fgr.data_manager import Data_Manager
from warnings import simplefilter
from pathlib import Path
from importlib import reload

# ignore some warnings
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# # Construct a Data Manager

# %%
# pipeline definition and data manager creation
data_path = Path(r'I:/My Drive/finger gesture recognition/')
pipeline = Data_Pipeline(base_data_files_path=data_path)  # configure the data pipeline you would like to use (check pipelines module for more info)
subject = 20
dm = Data_Manager([subject], pipeline)
print(dm.data_info())
# Out:
# Available experiments in the data manager: ['020_1_4', '020_1_2', '020_2_3', '020_2_2', '020_2_1', '020_2_4', '020_1_3', '020_1_1']
# Experiments format is: subject_session_position
# None

# %% [markdown]
# # task 1 - single subject, 80/20 train/test split from position 4 all sessions

# %% [markdown]
# ## data extraction

# %%
# extract datasets from the data manager - labels format: "<subject>_<session>_<position>_<gesture>_<iteration_number>"
dataset = dm.get_dataset(experiments=[f'{subject:03d}_*_4'], add_exp_name=True)

data = dataset[0]
labels = dataset[1]

# train test split
data_train, data_test, labels_train, labels_test = train_test_split_by_gesture(data, labels=labels, test_size=0.2)

# reshape the data to match the model architecture
data_train = data_train.reshape(data_train.shape[0], 1, 4, 4)  # reshape to fit the CNN input
data_test = data_test.reshape(data_test.shape[0], 1, 4, 4)  # reshape to fit the CNN input
# Out:
# Experiments in datasets: ['020_1_4', '020_2_4']
# Starting to extract datasets
# Loading experiments datasets:   0%|          | 0/2 [00:00<?, ?exp/s]
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.736, in the experiment: 020_2_4
# finished extracting the dataset
# number of gestures with only one repetition: 0
# Their names are: []

# %% [markdown]
# ## model training

# %%
# set and train a model (cv or not)
model = models.Net(num_classes=10, dropout_rate=0.1)
model.fit_model(data_train, labels_train, val_data=data_test, val_labels=labels_test, num_epochs=120, batch_size=64,
                lr=0.001, l2_weight=0.0001)
# Out:
# training model: 100%|██████████| 120/120 [03:17<00:00,  1.65s/epoch]
# Done Training!

# %% [markdown]
# ## model evaluation

# %%
model.evaluate_model(model.val_data, model.val_labels, cm_title=f'subject {subject} - task 1')
# Out:
# 0.975

# %% [markdown]
# # task 2 - single subject, 80/20 train/test split from all sessions

# %% [markdown]
# ## data extraction

# %%
# extract datasets from the data manager - labels format: "<subject>_<session>_<position>_<gesture>_<iteration_number>"
dataset = dm.get_dataset(experiments=[f'{subject:03d}_*_*'], add_exp_name=True)

data = dataset[0]
labels = dataset[1]

# train test split
data_train, data_test, labels_train, labels_test = train_test_split_by_gesture(data, labels=labels, test_size=0.2)

# reshape the data to match the model architecture
data_train = data_train.reshape(data_train.shape[0], 1, 4, 4)  # reshape to fit the CNN input
data_test = data_test.reshape(data_test.shape[0], 1, 4, 4)  # reshape to fit the CNN input
# Out:
# Experiments in datasets: ['020_1_4', '020_1_2', '020_2_3', '020_2_2', '020_2_1', '020_2_4', '020_1_3', '020_1_1']
# Starting to extract datasets
# Loading experiments datasets:   0%|          | 0/8 [00:00<?, ?exp/s]
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.931, in the experiment: 020_1_2
# C:\Users\tomer\Desktop\Fingers-Gesture-Recognition\Source\fgr\data_manager.py:538: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   curr_raw_edf = mne.io.read_raw_edf(file_name, preload=True, stim_channel='auto', verbose=False)
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.654, in the experiment: 020_2_3
# C:\Users\tomer\Desktop\Fingers-Gesture-Recognition\Source\fgr\data_manager.py:538: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   curr_raw_edf = mne.io.read_raw_edf(file_name, preload=True, stim_channel='auto', verbose=False)
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.227, in the experiment: 020_2_2
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.094, in the experiment: 020_2_1
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.25, in the experiment: 020_1_3
# Warning: annotation Start_Het_1 in time 634.022 in experiment 020_1_3 is a duplicate, removing it from the annotations. pls check the annotations in the raw files for further details.
# Warning: annotation Release_Het_1 in time 638.962 in experiment 020_1_3 is a duplicate, removing it from the annotations. pls check the annotations in the raw files for further details.
# Error: annotation mismatch, no Release/End annotation for Recording ed in time: 0.721, in the experiment: 020_1_1
# finished extracting the dataset
# number of gestures with only one repetition: 0
# Their names are: []

# %% [markdown]
# ## model training

# %%
# set and train a model (cv or not)
model = models.Net(num_classes=10, dropout_rate=0.1)
model.fit_model(data_train, labels_train, val_data=data_test, val_labels=labels_test, num_epochs=120, batch_size=64,
                lr=0.001, l2_weight=0.0001)
# Out:
# training model: 100%|██████████| 120/120 [13:07<00:00,  6.56s/epoch]
# Done Training!

# %% [markdown]
# ## model evaluation

# %%
model.evaluate_model(model.val_data, model.val_labels, cm_title=f'subject {subject} - task 1')
# Out:
# 0.8875

# %% [markdown]
# # task 3 - using 70% of session 2 as testing data (the rest is used for training)

# %% [markdown]
# ## data extraction

# %%
# extract datasets from the data manager - labels format: "<subject>_<session>_<position>_<gesture>_<iteration_number>"
dataset_1 = dm.get_dataset(experiments=[f'{subject:03d}_1_*'], add_exp_name=True)
dataset_2 = dm.get_dataset(experiments=[f'{subject:03d}_2_*'], add_exp_name=True)

data_1 = dataset_2[0]
labels_1 = dataset_2[1]

data_2 = dataset_1[0]
labels_2 = dataset_1[1]

# train test split
data_2_train, data_2_test, labels_2_train, labels_2_test = train_test_split_by_gesture(data_2, labels=labels_2, test_size=0.7)

# reshape the data to match the model architecture input
data_1 = data_1.reshape(data_1.shape[0], 1, 4, 4)
data_2_train = data_2_train.reshape(data_2_train.shape[0], 1, 4, 4)
data_2_test = data_2_test.reshape(data_2_test.shape[0], 1, 4, 4)
# Out:
# Experiments in datasets: ['020_1_4', '020_1_2', '020_1_3', '020_1_1']
# Starting to extract datasets
# Loading experiments datasets:   0%|          | 0/4 [00:00<?, ?exp/s]
# finished extracting the dataset
# Experiments in datasets: ['020_2_3', '020_2_2', '020_2_1', '020_2_4']
# Starting to extract datasets
# Loading experiments datasets:   0%|          | 0/4 [00:00<?, ?exp/s]
# finished extracting the dataset
# number of gestures with only one repetition: 0
# Their names are: []

# %% [markdown]
# ## model training

# %%
# set and train a model (cv or not)
model = models.Net(num_classes=10, dropout_rate=0.1)
# model = torch.compile(model)  # optimize for faster training
model.fit_model(data_1, labels_1, num_epochs=120, batch_size=64, lr=0.001, l2_weight=0.0001)
model.fit_model(data_2_train, labels_2_train, val_data=data_2_test, val_labels=labels_2_test, num_epochs=70,
                batch_size=64, lr=0.001, l2_weight=0.0001)
# Out:
# training model: 100%|██████████| 120/120 [07:46<00:00,  3.88s/epoch]
# Done Training!
# training model: 100%|██████████| 70/70 [01:37<00:00,  1.40s/epoch]
# Done Training!

# %% [markdown]
# ## model evaluation

# %%
model.evaluate_model(data_2_test, labels_2_test, cm_title=f'subject {subject} - task 2')
# Out:
# 0.8607142857142858
